# %%
# Imports and requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

#Import the requests library
import requests

#Import the API key.
from config import weather_api_keys

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add lotitude and longitude to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities.
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 760

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")

# Create counters.
record_count = 1
set_count =1
# Out:
# Beginning Data Retrieval

# %%
# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | namatanai
# Processing Record 8 of Set 1 | colares
# Processing Record 9 of Set 1 | valparai
# Processing Record 10 of Set 1 | bull savanna
# Processing Record 11 of Set 1 | rutul
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | komsomolskiy
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | garden city
# Processing Record 18 of Set 1 | sovetskiy
# Processing Record 19 of Set 1 | karratha
# Processing Record 20 of Set 1 | east london
# Processing Record 21 of Set 1 | jagannathpur
# Processing Record 22 of Set 1 | hovd
# Processing Record 23 of Set 1 | khash
# Processing Record 24 of Set 1 | yumen
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | coquimbo
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | bindura
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | dir
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | ilulissat
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | fort oglethorpe
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | hobyo
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | kaitangata
# Processing Record 1 of Set 2 | springbok
# Processing Record 2 of Set 2 | tura
# Processing Record 3 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | cacequi
# Processing Record 6 of Set 2 | ibra
# Processing Record 7 of Set 2 | lasa
# Processing Record 8 of Set 2 | sobolevo
# Processing Record 9 of Set 2 | wasilla
# Processing Record 10 of Set 2 | baghdad
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | antofagasta
# Processing Record 14 of Set 2 | sao joao da barra
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | ipira
# Processing Record 18 of Set 2 | quatre cocos
# Processing Record 19 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | agnibilekrou
# Processing Record 24 of Set 2 | ponta delgada
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | cruzeiro do sul
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | pemangkat
# Processing Record 31 of Set 2 | zhangzhou
# Processing Record 32 of Set 2 | thompson
# Processing Record 33 of Set 2 | acarau
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | trelew
# Processing Record 39 of Set 2 | cockburn town
# Processing Record 40 of Set 2 | conde
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | mindelo
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | labuhan
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 2 | jahrom
# City not found. Skipping...
# Processing Record 49 of Set 2 | yakeshi
# Processing Record 50 of Set 2 | meulaboh
# Processing Record 1 of Set 3 | bayji
# Processing Record 2 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 3 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | alasehir
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | damghan
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | tartus
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | zyryanka
# Processing Record 13 of Set 3 | llanes
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | beringovskiy
# Processing Record 17 of Set 3 | neepawa
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | tessalit
# Processing Record 20 of Set 3 | necochea
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | yerbogachen
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | qandala
# Processing Record 25 of Set 3 | mahebourg
# Processing Record 26 of Set 3 | miranda de ebro
# Processing Record 27 of Set 3 | bubaque
# Processing Record 28 of Set 3 | vokhtoga
# Processing Record 29 of Set 3 | hofn
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | asau
# Processing Record 34 of Set 3 | hinton
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | severnyy
# Processing Record 39 of Set 3 | doha
# Processing Record 40 of Set 3 | dholka
# Processing Record 41 of Set 3 | nishihara
# Processing Record 42 of Set 3 | progreso
# Processing Record 43 of Set 3 | inongo
# Processing Record 44 of Set 3 | san cristobal
# Processing Record 45 of Set 3 | kinsale
# Processing Record 46 of Set 3 | saint-georges
# Processing Record 47 of Set 3 | ancud
# Processing Record 48 of Set 3 | katsuura
# Processing Record 49 of Set 3 | hobart
# Processing Record 50 of Set 3 | chimbote
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | san andres
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | katunino
# Processing Record 5 of Set 4 | mackay
# Processing Record 6 of Set 4 | gondanglegi
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | vabalninkas
# Processing Record 9 of Set 4 | pisco
# Processing Record 10 of Set 4 | vostok
# Processing Record 11 of Set 4 | alta
# Processing Record 12 of Set 4 | matara
# Processing Record 13 of Set 4 | bhachau
# Processing Record 14 of Set 4 | zabol
# Processing Record 15 of Set 4 | waitati
# Processing Record 16 of Set 4 | liverpool
# Processing Record 17 of Set 4 | mehamn
# Processing Record 18 of Set 4 | mirnyy
# Processing Record 19 of Set 4 | buraydah
# Processing Record 20 of Set 4 | leh
# Processing Record 21 of Set 4 | vanimo
# Processing Record 22 of Set 4 | atuona
# Processing Record 23 of Set 4 | eureka
# Processing Record 24 of Set 4 | hambantota
# Processing Record 25 of Set 4 | des moines
# Processing Record 26 of Set 4 | liyang
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | maningrida
# Processing Record 29 of Set 4 | allapalli
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | zelenoborsk
# Processing Record 32 of Set 4 | tevaitoa
# Processing Record 33 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 4 | ruwi
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | pavlovka
# Processing Record 37 of Set 4 | destin
# Processing Record 38 of Set 4 | nikolskoye
# Processing Record 39 of Set 4 | lannion
# Processing Record 40 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 4 | jejuri
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | roebourne
# Processing Record 44 of Set 4 | santomera
# Processing Record 45 of Set 4 | cayenne
# Processing Record 46 of Set 4 | huanuco
# Processing Record 47 of Set 4 | koslan
# Processing Record 48 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 4 | bulgan
# Processing Record 50 of Set 4 | miri
# Processing Record 1 of Set 5 | ayan
# Processing Record 2 of Set 5 | sao filipe
# Processing Record 3 of Set 5 | severodvinsk
# Processing Record 4 of Set 5 | bafra
# Processing Record 5 of Set 5 | mount pleasant
# Processing Record 6 of Set 5 | laguna
# Processing Record 7 of Set 5 | paraiso
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | velikie luki
# City not found. Skipping...
# Processing Record 10 of Set 5 | kununurra
# Processing Record 11 of Set 5 | kuva
# City not found. Skipping...
# Processing Record 12 of Set 5 | tanout
# Processing Record 13 of Set 5 | vila franca do campo
# Processing Record 14 of Set 5 | waingapu
# Processing Record 15 of Set 5 | havoysund
# Processing Record 16 of Set 5 | gushikawa
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | avera
# Processing Record 20 of Set 5 | beloha
# Processing Record 21 of Set 5 | the valley
# Processing Record 22 of Set 5 | sangar
# Processing Record 23 of Set 5 | benghazi
# Processing Record 24 of Set 5 | lebu
# Processing Record 25 of Set 5 | himatnagar
# Processing Record 26 of Set 5 | bayan
# Processing Record 27 of Set 5 | calabozo
# Processing Record 28 of Set 5 | hithadhoo
# Processing Record 29 of Set 5 | baruun-urt
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | urengoy
# Processing Record 32 of Set 5 | atambua
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | sakaiminato
# Processing Record 35 of Set 5 | georgiyevka
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | noumea
# Processing Record 39 of Set 5 | sungaipenuh
# Processing Record 40 of Set 5 | lompoc
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | yerkoy
# Processing Record 43 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 5 | simbahan
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | mega
# Processing Record 47 of Set 5 | mandalay
# Processing Record 48 of Set 5 | husavik
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | zolotukhino
# Processing Record 1 of Set 6 | ucluelet
# Processing Record 2 of Set 6 | half moon bay
# Processing Record 3 of Set 6 | sarana
# Processing Record 4 of Set 6 | qasigiannguit
# Processing Record 5 of Set 6 | atikokan
# Processing Record 6 of Set 6 | linxia
# Processing Record 7 of Set 6 | colac
# Processing Record 8 of Set 6 | campos
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | saldanha
# Processing Record 11 of Set 6 | birao
# Processing Record 12 of Set 6 | oranjestad
# Processing Record 13 of Set 6 | yaan
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | katima mulilo
# Processing Record 16 of Set 6 | puerto ayora
# Processing Record 17 of Set 6 | illela
# Processing Record 18 of Set 6 | sao jose da coroa grande
# Processing Record 19 of Set 6 | omboue
# Processing Record 20 of Set 6 | saint anthony
# Processing Record 21 of Set 6 | bonavista
# Processing Record 22 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 6 | dno
# Processing Record 24 of Set 6 | barcelos
# Processing Record 25 of Set 6 | klaksvik
# Processing Record 26 of Set 6 | torbay
# Processing Record 27 of Set 6 | araguatins
# City not found. Skipping...
# Processing Record 28 of Set 6 | nome
# Processing Record 29 of Set 6 | denpasar
# Processing Record 30 of Set 6 | kawalu
# Processing Record 31 of Set 6 | whyalla
# Processing Record 32 of Set 6 | cay
# Processing Record 33 of Set 6 | dumai
# Processing Record 34 of Set 6 | aquiraz
# Processing Record 35 of Set 6 | kedrovyy
# Processing Record 36 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 6 | lavrentiya
# Processing Record 38 of Set 6 | ierapetra
# Processing Record 39 of Set 6 | taltal
# Processing Record 40 of Set 6 | houma
# Processing Record 41 of Set 6 | khatanga
# Processing Record 42 of Set 6 | emba
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | tamasane
# Processing Record 45 of Set 6 | zhangdian
# Processing Record 46 of Set 6 | xichang
# Processing Record 47 of Set 6 | katangli
# Processing Record 48 of Set 6 | zavetnoye
# Processing Record 49 of Set 6 | kidodi
# Processing Record 50 of Set 6 | chokurdakh
# Processing Record 1 of Set 7 | nanakuli
# Processing Record 2 of Set 7 | dudinka
# Processing Record 3 of Set 7 | aripuana
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | nelson bay
# Processing Record 6 of Set 7 | norden
# Processing Record 7 of Set 7 | gillette
# Processing Record 8 of Set 7 | tahe
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | strezhevoy
# Processing Record 11 of Set 7 | si chiang mai
# Processing Record 12 of Set 7 | sitio novo do tocantins
# Processing Record 13 of Set 7 | kulu
# Processing Record 14 of Set 7 | ostrovnoy
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | saint-augustin
# Processing Record 17 of Set 7 | agadir
# Processing Record 18 of Set 7 | pacific grove
# Processing Record 19 of Set 7 | gualeguay
# Processing Record 20 of Set 7 | kasane
# Processing Record 21 of Set 7 | riberalta
# Processing Record 22 of Set 7 | aklavik
# Processing Record 23 of Set 7 | kavaratti
# Processing Record 24 of Set 7 | stornoway
# Processing Record 25 of Set 7 | mama
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | kapit
# Processing Record 28 of Set 7 | saint-denis
# Processing Record 29 of Set 7 | chapada dos guimaraes
# Processing Record 30 of Set 7 | nikolsk
# Processing Record 31 of Set 7 | seydi
# Processing Record 32 of Set 7 | lara
# Processing Record 33 of Set 7 | namibe
# Processing Record 34 of Set 7 | rio gallegos
# Processing Record 35 of Set 7 | norman wells
# Processing Record 36 of Set 7 | antequera
# Processing Record 37 of Set 7 | ballarat
# Processing Record 38 of Set 7 | rumuruti
# Processing Record 39 of Set 7 | mocajuba
# Processing Record 40 of Set 7 | margherita
# Processing Record 41 of Set 7 | plettenberg bay
# Processing Record 42 of Set 7 | thiruvananthapuram
# Processing Record 43 of Set 7 | pangody
# Processing Record 44 of Set 7 | iwanai
# Processing Record 45 of Set 7 | monroe
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | maiduguri
# Processing Record 48 of Set 7 | tamandare
# Processing Record 49 of Set 7 | road town
# Processing Record 50 of Set 7 | banes
# Processing Record 1 of Set 8 | pudozh
# Processing Record 2 of Set 8 | jizan
# Processing Record 3 of Set 8 | hulan
# Processing Record 4 of Set 8 | gizo
# Processing Record 5 of Set 8 | manokwari
# Processing Record 6 of Set 8 | bambanglipuro
# Processing Record 7 of Set 8 | opuwo
# Processing Record 8 of Set 8 | piacabucu
# Processing Record 9 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 8 | coromandel
# Processing Record 11 of Set 8 | nisia floresta
# Processing Record 12 of Set 8 | novyy urengoy
# Processing Record 13 of Set 8 | tawau
# Processing Record 14 of Set 8 | middle island
# Processing Record 15 of Set 8 | oriximina
# Processing Record 16 of Set 8 | tukrah
# Processing Record 17 of Set 8 | nipawin
# Processing Record 18 of Set 8 | vammala
# Processing Record 19 of Set 8 | plerin
# Processing Record 20 of Set 8 | heilbron
# Processing Record 21 of Set 8 | teya
# Processing Record 22 of Set 8 | japura
# Processing Record 23 of Set 8 | tyrma
# Processing Record 24 of Set 8 | adwa
# Processing Record 25 of Set 8 | port macquarie
# Processing Record 26 of Set 8 | roald
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | salinas
# Processing Record 29 of Set 8 | gopalganj
# Processing Record 30 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 32 of Set 8 | general roca
# Processing Record 33 of Set 8 | alice springs
# Processing Record 34 of Set 8 | clyde river
# Processing Record 35 of Set 8 | muros
# Processing Record 36 of Set 8 | gazanjyk
# Processing Record 37 of Set 8 | misratah
# Processing Record 38 of Set 8 | tecuala
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 8 | houlung
# City not found. Skipping...
# Processing Record 42 of Set 8 | santander
# Processing Record 43 of Set 8 | uppsala
# Processing Record 44 of Set 8 | shenjiamen
# Processing Record 45 of Set 8 | manono
# Processing Record 46 of Set 8 | adrar
# Processing Record 47 of Set 8 | rio grande
# Processing Record 48 of Set 8 | cao bang
# Processing Record 49 of Set 8 | rosetta
# Processing Record 50 of Set 8 | sri aman
# Processing Record 1 of Set 9 | plouzane
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | sorong
# Processing Record 4 of Set 9 | swan hill
# Processing Record 5 of Set 9 | gimli
# Processing Record 6 of Set 9 | mizan teferi
# Processing Record 7 of Set 9 | babstovo
# Processing Record 8 of Set 9 | north adams
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | san clemente
# Processing Record 11 of Set 9 | los llanos de aridane
# Processing Record 12 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 9 | san jose
# Processing Record 14 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 9 | iqaluit
# Processing Record 16 of Set 9 | la libertad
# Processing Record 17 of Set 9 | ribas do rio pardo
# Processing Record 18 of Set 9 | takaungu
# Processing Record 19 of Set 9 | urumqi
# Processing Record 20 of Set 9 | egvekinot
# Processing Record 21 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 9 | taguatinga
# Processing Record 23 of Set 9 | coihueco
# Processing Record 24 of Set 9 | garhakota
# Processing Record 25 of Set 9 | lufilufi
# Processing Record 26 of Set 9 | ormara
# Processing Record 27 of Set 9 | rosarito
# Processing Record 28 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 9 | bac lieu
# Processing Record 30 of Set 9 | bandar-e lengeh
# Processing Record 31 of Set 9 | cariamanga
# Processing Record 32 of Set 9 | ekhabi
# Processing Record 33 of Set 9 | oktyabrskoye
# Processing Record 34 of Set 9 | jingdezhen
# Processing Record 35 of Set 9 | galesong
# Processing Record 36 of Set 9 | lesnoy
# Processing Record 37 of Set 9 | aden
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | blind river
# Processing Record 40 of Set 9 | tezu
# Processing Record 41 of Set 9 | hay river
# Processing Record 42 of Set 9 | udachnyy
# Processing Record 43 of Set 9 | tinqueux
# Processing Record 44 of Set 9 | mount gambier
# Processing Record 45 of Set 9 | kavieng
# Processing Record 46 of Set 9 | tautira
# Processing Record 47 of Set 9 | alindao
# Processing Record 48 of Set 9 | naze
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 10 | buala
# Processing Record 2 of Set 10 | istok
# Processing Record 3 of Set 10 | lagoa
# Processing Record 4 of Set 10 | fengzhen
# Processing Record 5 of Set 10 | alofi
# Processing Record 6 of Set 10 | wanning
# Processing Record 7 of Set 10 | tosya
# Processing Record 8 of Set 10 | orlik
# Processing Record 9 of Set 10 | mana
# Processing Record 10 of Set 10 | nantucket
# Processing Record 11 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 12 of Set 10 | chifeng
# Processing Record 13 of Set 10 | podor
# Processing Record 14 of Set 10 | nata
# Processing Record 15 of Set 10 | zhezkazgan
# Processing Record 16 of Set 10 | penalva
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | celestun
# Processing Record 20 of Set 10 | rorvik
# Processing Record 21 of Set 10 | lumsden
# Processing Record 22 of Set 10 | mayo
# Processing Record 23 of Set 10 | bugalagrande
# Processing Record 24 of Set 10 | penzance
# Processing Record 25 of Set 10 | korla
# Processing Record 26 of Set 10 | morki
# Processing Record 27 of Set 10 | bathsheba
# Processing Record 28 of Set 10 | grindavik
# Processing Record 29 of Set 10 | nara
# Processing Record 30 of Set 10 | olinda
# Processing Record 31 of Set 10 | tiarei
# Processing Record 32 of Set 10 | oliver
# Processing Record 33 of Set 10 | kaeo
# Processing Record 34 of Set 10 | perumpavur
# Processing Record 35 of Set 10 | inuvik
# Processing Record 36 of Set 10 | pyaozerskiy
# Processing Record 37 of Set 10 | kadaya
# Processing Record 38 of Set 10 | virginia beach
# Processing Record 39 of Set 10 | dzaoudzi
# Processing Record 40 of Set 10 | jarvenpaa
# Processing Record 41 of Set 10 | aranos
# Processing Record 42 of Set 10 | luganville
# Processing Record 43 of Set 10 | abu zabad
# Processing Record 44 of Set 10 | mandapam
# Processing Record 45 of Set 10 | san quintin
# Processing Record 46 of Set 10 | broome
# Processing Record 47 of Set 10 | kattivakkam
# Processing Record 48 of Set 10 | iskilip
# Processing Record 49 of Set 10 | port hardy
# Processing Record 50 of Set 10 | krasnogorskoye
# Processing Record 1 of Set 11 | nokaneng
# Processing Record 2 of Set 11 | skelleftea
# Processing Record 3 of Set 11 | fallon
# Processing Record 4 of Set 11 | cooma
# Processing Record 5 of Set 11 | lohr
# Processing Record 6 of Set 11 | urubicha
# Processing Record 7 of Set 11 | bay roberts
# Processing Record 8 of Set 11 | kalofer
# Processing Record 9 of Set 11 | nemuro
# Processing Record 10 of Set 11 | alihe
# Processing Record 11 of Set 11 | kongolo
# Processing Record 12 of Set 11 | carauari
# Processing Record 13 of Set 11 | el badari
# City not found. Skipping...
# Processing Record 14 of Set 11 | pundaguitan
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | sioux lookout
# Processing Record 17 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 11 | fairbanks
# Processing Record 19 of Set 11 | constantine
# Processing Record 20 of Set 11 | mersing
# Processing Record 21 of Set 11 | yuli
# Processing Record 22 of Set 11 | puerto santander
# Processing Record 23 of Set 11 | abha
# Processing Record 24 of Set 11 | arlit
# Processing Record 25 of Set 11 | calama
# Processing Record 26 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 11 | souillac
# Processing Record 29 of Set 11 | aykhal
# Processing Record 30 of Set 11 | alamogordo
# Processing Record 31 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 11 | bontang
# Processing Record 35 of Set 11 | oltu
# Processing Record 36 of Set 11 | kharan
# Processing Record 37 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 38 of Set 11 | palmer
# Processing Record 39 of Set 11 | jiaozuo
# Processing Record 40 of Set 11 | sompeta
# Processing Record 41 of Set 11 | alyangula
# Processing Record 42 of Set 11 | hualmay
# Processing Record 43 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 11 | tuatapere
# Processing Record 45 of Set 11 | bahar
# Processing Record 46 of Set 11 | najran
# Processing Record 47 of Set 11 | durazno
# Processing Record 48 of Set 11 | hami
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | carsamba
# Processing Record 1 of Set 12 | hirara
# Processing Record 2 of Set 12 | okmulgee
# Processing Record 3 of Set 12 | samdari
# Processing Record 4 of Set 12 | ankazobe
# Processing Record 5 of Set 12 | kalmunai
# Processing Record 6 of Set 12 | erenhot
# Processing Record 7 of Set 12 | katherine
# Processing Record 8 of Set 12 | coulommiers
# Processing Record 9 of Set 12 | dongkan
# Processing Record 10 of Set 12 | kolondieba
# Processing Record 11 of Set 12 | oga
# Processing Record 12 of Set 12 | nagato
# Processing Record 13 of Set 12 | la sarre
# Processing Record 14 of Set 12 | sarreguemines
# Processing Record 15 of Set 12 | elbrus
# Processing Record 16 of Set 12 | batagay-alyta
# Processing Record 17 of Set 12 | vanavara
# Processing Record 18 of Set 12 | sehithwa
# Processing Record 19 of Set 12 | berbera
# Processing Record 20 of Set 12 | helong
# Processing Record 21 of Set 12 | paranapanema
# Processing Record 22 of Set 12 | abalak
# Processing Record 23 of Set 12 | baker city
# Processing Record 24 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 12 | kamenka
# Processing Record 26 of Set 12 | dunedin
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | priargunsk
# Processing Record 29 of Set 12 | trimbak
# Processing Record 30 of Set 12 | bardiyah
# Processing Record 31 of Set 12 | cotonou
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | atar
# Processing Record 34 of Set 12 | el copey
# Processing Record 35 of Set 12 | asyut
# Processing Record 36 of Set 12 | veraval
# Processing Record 37 of Set 12 | zhuhai
# Processing Record 38 of Set 12 | araguari
# Processing Record 39 of Set 12 | kroya
# Processing Record 40 of Set 12 | poum
# Processing Record 41 of Set 12 | nouadhibou
# Processing Record 42 of Set 12 | kungurtug
# Processing Record 43 of Set 12 | kita
# Processing Record 44 of Set 12 | znamenskoye
# Processing Record 45 of Set 12 | berlevag
# Processing Record 46 of Set 12 | bonanza
# Processing Record 47 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 48 of Set 12 | bilma
# Processing Record 49 of Set 12 | fare
# Processing Record 50 of Set 12 | tolga
# Processing Record 1 of Set 13 | knysna
# Processing Record 2 of Set 13 | puri
# Processing Record 3 of Set 13 | sena madureira
# Processing Record 4 of Set 13 | bandarbeyla
# Processing Record 5 of Set 13 | maldonado
# Processing Record 6 of Set 13 | kiruna
# Processing Record 7 of Set 13 | santiago
# Processing Record 8 of Set 13 | boshnyakovo
# Processing Record 9 of Set 13 | bonthe
# Processing Record 10 of Set 13 | juegang
# Processing Record 11 of Set 13 | sistranda
# Processing Record 12 of Set 13 | marawi
# Processing Record 13 of Set 13 | hengyang
# Processing Record 14 of Set 13 | khorixas
# Processing Record 15 of Set 13 | belle fourche
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | zhigansk
# Processing Record 18 of Set 13 | abapo
# Processing Record 19 of Set 13 | shetpe
# Processing Record 20 of Set 13 | ukiah
# Processing Record 21 of Set 13 | coahuayana
# Processing Record 22 of Set 13 | lata
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | yanam
# Processing Record 25 of Set 13 | havre-saint-pierre
# Processing Record 26 of Set 13 | rehoboth
# Processing Record 27 of Set 13 | koumac
# Processing Record 28 of Set 13 | sur
# Processing Record 29 of Set 13 | tambacounda
# Processing Record 30 of Set 13 | pryluky
# Processing Record 31 of Set 13 | plyussa
# Processing Record 32 of Set 13 | kidal
# Processing Record 33 of Set 13 | acapulco
# Processing Record 34 of Set 13 | xanxere
# Processing Record 35 of Set 13 | gigmoto
# Processing Record 36 of Set 13 | gwadar
# Processing Record 37 of Set 13 | surt
# Processing Record 38 of Set 13 | honiara
# Processing Record 39 of Set 13 | wanaka
# Processing Record 40 of Set 13 | novikovo
# Processing Record 41 of Set 13 | ambilobe
# Processing Record 42 of Set 13 | lamu
# Processing Record 43 of Set 13 | bilibino
# Processing Record 44 of Set 13 | codrington
# Processing Record 45 of Set 13 | lhokseumawe
# Processing Record 46 of Set 13 | touros
# Processing Record 47 of Set 13 | luba
# Processing Record 48 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 13 | ojinaga
# Processing Record 50 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 14 | san luis
# Processing Record 2 of Set 14 | valentin gomez farias
# Processing Record 3 of Set 14 | ahipara
# Processing Record 4 of Set 14 | yulara
# Processing Record 5 of Set 14 | tadine
# Processing Record 6 of Set 14 | arkhangelos
# City not found. Skipping...
# Processing Record 7 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 14 | huilong
# Processing Record 9 of Set 14 | ca mau
# Processing Record 10 of Set 14 | chirongui
# Processing Record 11 of Set 14 | ketegyhaza
# Processing Record 12 of Set 14 | palu
# Processing Record 13 of Set 14 | sambava
# Processing Record 14 of Set 14 | micheweni
# Processing Record 15 of Set 14 | wewak
# Processing Record 16 of Set 14 | ughelli
# Processing Record 17 of Set 14 | tilichiki
# Processing Record 18 of Set 14 | shimoda
# Processing Record 19 of Set 14 | andenes
# Processing Record 20 of Set 14 | asfi
# Processing Record 21 of Set 14 | gannan
# Processing Record 22 of Set 14 | bowen
# Processing Record 23 of Set 14 | saint-joseph
# Processing Record 24 of Set 14 | jasper
# Processing Record 25 of Set 14 | cuamba
# Processing Record 26 of Set 14 | carnot
# Processing Record 27 of Set 14 | pimentel
# Processing Record 28 of Set 14 | hervey bay
# Processing Record 29 of Set 14 | cookshire
# City not found. Skipping...
# Processing Record 30 of Set 14 | canita
# Processing Record 31 of Set 14 | portland
# Processing Record 32 of Set 14 | kenora
# Processing Record 33 of Set 14 | labuan
# Processing Record 34 of Set 14 | rock sound
# Processing Record 35 of Set 14 | ust-uda
# Processing Record 36 of Set 14 | garissa
# Processing Record 37 of Set 14 | stromness
# Processing Record 38 of Set 14 | mount isa
# Processing Record 39 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | linshu
# City not found. Skipping...
# Processing Record 41 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 14 | merauke
# Processing Record 43 of Set 14 | puertollano
# Processing Record 44 of Set 14 | revda
# Processing Record 45 of Set 14 | khandyga
# Processing Record 46 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 14 | coihaique
# Processing Record 48 of Set 14 | brigantine
# Processing Record 49 of Set 14 | labrea
# Processing Record 50 of Set 14 | nehe
# Processing Record 1 of Set 15 | tabou
# Processing Record 2 of Set 15 | sampit
# Processing Record 3 of Set 15 | gulu
# Processing Record 4 of Set 15 | harper
# Processing Record 5 of Set 15 | preobrazheniye
# Processing Record 6 of Set 15 | kamina
# Processing Record 7 of Set 15 | genhe
# Processing Record 8 of Set 15 | xiangxiang
# Processing Record 9 of Set 15 | polovinnoye
# Processing Record 10 of Set 15 | lyuban
# Processing Record 11 of Set 15 | kedougou
# Processing Record 12 of Set 15 | konya
# Processing Record 13 of Set 15 | haapu
# City not found. Skipping...
# Processing Record 14 of Set 15 | nogales
# Processing Record 15 of Set 15 | plast
# Processing Record 16 of Set 15 | astoria
# Processing Record 17 of Set 15 | padang
# Processing Record 18 of Set 15 | macia
# Processing Record 19 of Set 15 | esna
# Processing Record 20 of Set 15 | bouna
# Processing Record 21 of Set 15 | ornskoldsvik
# Processing Record 22 of Set 15 | baykit
# Processing Record 23 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | torrelavega
# Processing Record 25 of Set 15 | lucea
# Processing Record 26 of Set 15 | fukuchiyama
# Processing Record 27 of Set 15 | la ronge
# Processing Record 28 of Set 15 | tobane
# Processing Record 29 of Set 15 | flinders
# Processing Record 30 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 15 | baiyin
# Processing Record 33 of Set 15 | belyy yar
# Processing Record 34 of Set 15 | malmesbury
# Processing Record 35 of Set 15 | lagunas
# Processing Record 36 of Set 15 | ternate
# Processing Record 37 of Set 15 | libertador general san martin
# Processing Record 38 of Set 15 | iuna
# Processing Record 39 of Set 15 | pringsewu
# Processing Record 40 of Set 15 | biak
# Processing Record 41 of Set 15 | wheeling
# Processing Record 42 of Set 15 | tamiahua
# Processing Record 43 of Set 15 | mareeba
# Processing Record 44 of Set 15 | mildura
# Processing Record 45 of Set 15 | monster
# Processing Record 46 of Set 15 | sao felix do xingu
# Processing Record 47 of Set 15 | nortelandia
# Processing Record 48 of Set 15 | shu
# Processing Record 49 of Set 15 | sept-iles
# Processing Record 50 of Set 15 | samarai
# Processing Record 1 of Set 16 | mitake
# Processing Record 2 of Set 16 | kleck
# City not found. Skipping...
# Processing Record 3 of Set 16 | santiago del estero
# Processing Record 4 of Set 16 | bandundu
# Processing Record 5 of Set 16 | antsohihy
# Processing Record 6 of Set 16 | northam
# Processing Record 7 of Set 16 | umm kaddadah
# Processing Record 8 of Set 16 | sfantu gheorghe
# Processing Record 9 of Set 16 | george town
# Processing Record 10 of Set 16 | inirida
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Itoman      JP  26.12  127.67     78.80        88          75
# 1          Mehamn      NO  71.04   27.85     32.00        92          40
# 2          Kodiak      US  57.79 -152.41     39.20        60           1
# 3          Yarada      IN  17.65   83.27     82.40        94          90
# 4         Mataura      NZ -46.19  168.86     45.00        77          94
# 5         Rikitea      PF -23.12 -134.97     73.54        68          40
# 6  Saint-Augustin      CA  51.23  -58.65     44.06        57           1
# 7       Ilulissat      GL  69.22  -51.10     33.80        59          75
# 8        Dengzhou      CN  37.81  120.75     57.72        42           0
# 9       Busselton      AU -33.65  115.33     55.00        64           0
#
#    Wind Speed          Current Description
# 0        8.05  light intensity shower rain
# 1        8.05             scattered clouds
# 2       12.75                    clear sky
# 3        2.24         heavy intensity rain
# 4        1.99              overcast clouds
# 5        8.70             scattered clouds
# 6        6.33                    clear sky
# 7       11.41                broken clouds
# 8       17.22                    clear sky
# 9       12.17                    clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_DataBase.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
